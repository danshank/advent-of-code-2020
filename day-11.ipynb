# %%
file = open("day-11-input", "r")
seating = file.read().splitlines()

def isOutsideOfSeating(i, j, seating):
    return i < 0 or j < 0 or i >= len(seating) or j >= len(seating[i])

def isOccupied(i, j, seating):
    if isOutsideOfSeating(i, j, seating):
        return False
    else:
        return seating[i][j] == '#'

def numberOccupied(i, j, seating):
    return (
        isOccupied(i-1, j-1, seating)
        + isOccupied(i-1, j, seating) 
        + isOccupied(i-1, j+1, seating) 
        + isOccupied(i, j-1, seating) 
        + isOccupied(i, j+1, seating) 
        + isOccupied(i+1, j-1, seating) 
        + isOccupied(i+1, j, seating) 
        + isOccupied(i+1, j+1, seating)
    )
    
def isSeat(i, j, seating):
    return seating[i][j] == 'L' or seating[i][j] == '#'

def createNewSeating(seating):
    newSeating = []
    changed = False
    for i in range(0, len(seating)):
        newRow = []
        for j in range(0, len(seating[i])):
            if isSeat(i, j, seating):
                x = numberOccupied(i, j, seating)
                if x == 0:
                    newRow.append('#')
                    changed = seating[i][j] == 'L' or changed
                elif x > 3:
                    newRow.append('L')
                    changed = seating[i][j] == '#' or changed
                else:
                    newRow.append(seating[i][j])
            else:
                newRow.append(seating[i][j])
        newSeating.append(newRow)
    return (newSeating, changed)
        
def countOccupied(seating):
    x = 0
    for i in range(0, len(seating)):
        for j in range(0, len(seating[i])):
            x = x + isOccupied(i, j, seating)
    return x

def formatSeating(seating):
    s = ""
    for row in seating:
        for seat in row:
            s = s + seat
        s = s + '\n'
    return s
        
wasChanged = True
n = 1

while wasChanged:
    print(f"Run {n}")
    seating, wasChanged = createNewSeating(seating)
    n = n + 1

print(formatSeating(seating))
print("\n")

#seating, wasChanged = createNewSeating(seating)

#print(isOccupied(-1, 0, seating))

ans = countOccupied(seating)
print(ans)
# Out:
# Run 1
# Run 2
# Run 3
# Run 4
# Run 5
# Run 6
# Run 7
# Run 8
# Run 9
# Run 10
# Run 11
# Run 12
# Run 13
# Run 14
# Run 15
# Run 16
# Run 17
# Run 18
# Run 19
# Run 20
# Run 21
# Run 22
# Run 23
# Run 24
# Run 25
# Run 26
# Run 27
# Run 28
# Run 29
# Run 30
# Run 31
# Run 32
# Run 33
# Run 34
# Run 35
# Run 36
# Run 37
# Run 38
# Run 39
# Run 40
# Run 41
# Run 42
# Run 43
# Run 44
# Run 45
# Run 46
# Run 47
# Run 48
# Run 49
# Run 50
# Run 51
# Run 52
# Run 53
# Run 54
# Run 55
# Run 56
# Run 57
# Run 58
# Run 59
# Run 60
# Run 61
# Run 62
# Run 63
# Run 64
# Run 65
# Run 66
# Run 67
# Run 68
# Run 69
# Run 70
# Run 71
# Run 72
# Run 73
# Run 74
# Run 75
# Run 76
# Run 77
# Run 78
# Run 79
# Run 80
# Run 81
# Run 82
# Run 83
# Run 84
# Run 85
# Run 86
# #L#L##L#L#.#L#L.#L#L#L#L#L#L#L#L#L#L#L#L#L#.#L#L#L#L#.L#L#L#L#.#L#L#L#L#L.L#L##L#L..#L#L#L#L#
# LLLLLLLLLL.LLLLLLLLLLLLLL.LLLLLLLL.LLLLLLLL.LLLL.LLLLLLLLLLLLL.LLLLLLLLLL#LL.LLLLL#LLLLLLLLLL
# ...

# %%
file = open("day-11-input", "r")
seating = file.read().splitlines()

def isOutsideOfSeating(i, j, seating):
    return i < 0 or j < 0 or i >= len(seating) or j >= len(seating[i])

def isOccupied(i, j, seating):
    if isOutsideOfSeating(i, j, seating):
        return False
    else:
        return seating[i][j] == '#'

def lineIsOccupied(i, dy, j, dx, seating):
    i = i + dy
    j = j + dx
    while not isOutsideOfSeating(i, j, seating):
        if isSeat(i, j, seating):
            return isOccupied(i, j, seating)
        i = i + dy
        j = j + dx
    return False
    
    
def numberOccupied(i, j, seating):
    return (
        lineIsOccupied(i, -1, j, -1, seating)
        + lineIsOccupied(i, -1, j, 0, seating) 
        + lineIsOccupied(i, -1, j, 1, seating) 
        + lineIsOccupied(i, 0, j, -1, seating) 
        + lineIsOccupied(i, 0, j, 1, seating) 
        + lineIsOccupied(i, 1, j, -1, seating) 
        + lineIsOccupied(i, 1, j, 0, seating) 
        + lineIsOccupied(i, 1, j, 1, seating)
    )
    
def isSeat(i, j, seating):
    return seating[i][j] == 'L' or seating[i][j] == '#'

def createNewSeating(seating):
    newSeating = []
    changed = False
    for i in range(0, len(seating)):
        newRow = []
        for j in range(0, len(seating[i])):
            if isSeat(i, j, seating):
                x = numberOccupied(i, j, seating)
                if x == 0:
                    newRow.append('#')
                    changed = seating[i][j] == 'L' or changed
                elif x > 4:
                    newRow.append('L')
                    changed = seating[i][j] == '#' or changed
                else:
                    newRow.append(seating[i][j])
            else:
                newRow.append(seating[i][j])
        newSeating.append(newRow)
    return (newSeating, changed)
        
def countOccupied(seating):
    x = 0
    for i in range(0, len(seating)):
        for j in range(0, len(seating[i])):
            x = x + isOccupied(i, j, seating)
    return x

def formatSeating(seating):
    s = ""
    for row in seating:
        for seat in row:
            s = s + seat
        s = s + '\n'
    return s
        
wasChanged = True
n = 1

while wasChanged:
    print(f"Run {n}")
    seating, wasChanged = createNewSeating(seating)
#    print(formatSeating(seating))
#    print("\n\n")
    n = n + 1



#print(numberOccupied(0, 3, seating))

ans = countOccupied(seating)
print(ans)
# Out:
# Run 1
# #.##.##.##
# #######.##
# #.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# ##########
# #.######.#
# #.#####.##
#
#
#
#
# Run 2
# #.LL.LL.L#
# #LLLLLL.LL
# L.L.L..L..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLLL.L
# #.LLLLL.L#
#
#
#
#
# Run 3
# #.L#.##.L#
# #L#####.LL
# L.#.#..#..
# ##L#.##.##
# #.##.#L.##
# #.#####.#L
# ..#.#.....
# LLL####LL#
# #.L#####.L
# #.L####.L#
#
#
#
#
# Run 4
# #.L#.L#.L#
# #LLLLLL.LL
# L.L.L..#..
# ##LL.LL.L#
# L.LL.LL.L#
# #.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLL#.L
# #.L#LL#.L#
#
#
#
#
# Run 5
# #.L#.L#.L#
# #LLLLLL.LL
# L.L.L..#..
# ##L#.#L.L#
# L.L#.#L.L#
# #.L####.LL
# ..#.#.....
# LLL###LLL#
# #.LLLLL#.L
# #.L#LL#.L#
#
#
#
#
# Run 6
# #.L#.L#.L#
# #LLLLLL.LL
# L.L.L..#..
# ##L#.#L.L#
# L.L#.LL.L#
# #.LLLL#.LL
# ..#.L.....
# LLL###LLL#
# #.LLLLL#.L
# #.L#LL#.L#
#
#
#
#
# Run 7
# #.L#.L#.L#
# #LLLLLL.LL
# L.L.L..#..
# ##L#.#L.L#
# L.L#.LL.L#
# #.LLLL#.LL
# ..#.L.....
# LLL###LLL#
# ...
