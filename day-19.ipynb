# %%
import re

def processNumberNode(x, processedNodes, unprocessedNodes):
    if not x in processedNodes:
        processedNodes[x] = RuleNode(x, processedNodes, unprocessedNodes)
    return processedNodes[x]
    

class RuleNode:
    def __init__(self, n, processedNodes, unprocessedNodes):
        tokens = unprocessedNodes[n]
        self.isVal = False
        if '|' in tokens:     
            self.isChoice = True
            self.firstChoice = []
            self.secondChoice = []
            orIndex = tokens.index('|')
            for token in tokens[0: orIndex]:
                self.firstChoice.append(processNumberNode(int(token), processedNodes, unprocessedNodes))
            for token in tokens[orIndex + 1:]:
                self.secondChoice.append(processNumberNode(int(token), processedNodes, unprocessedNodes))
        else:
            self.isChoice = False
            if tokens[0] == '"a"':
                self.isVal = True
                self.val = 'a'
            elif tokens[0] == '"b"':
                self.isVal = True
                self.val = 'b'
            else:
                self.rule = []
                for token in tokens:
                    self.rule.append(processNumberNode(int(token), processedNodes, unprocessedNodes))
        
    def createMatchingString(self):
        matchingStrings = set()
        if self.isVal:
            matchingStrings.add(self.val)
        elif self.isChoice:
            for choices in self.firstChoice:
            firstChoice0MatchingStrings = self.firstChoice[0].createMatchingString()
            firstChoice1MatchingStrings = self.firstChoice[1].createMatchingString()
            firstChoice = self.combineMatchingStrings(firstChoice0MatchingStrings, firstChoice1MatchingStrings)
            secondChoice0MatchingStrings = self.secondChoice[0].createMatchingString()
            secondChoice1MatchingStrings = self.secondChoice[1].createMatchingString()
            secondChoice = combineMatchingStrings(secondChoice0MatchingStrings, secondChoice1MatchingStrings)
            matchingStrings = firstChoice.union(secondChoice)
        else:
            firstMatchingStrings = self.rule[0].createMatchingString()
            secondMatchingStrings = self.rule[1].createMatchingString()
            matchingStrings = self.combineMatchingStrings(firstMatchingStrings, secondMatchingStrings)
        return matchingStrings
    
    def combineMatchingStrings(S, T):
        matchingStrings = set()
        for s in firstMatchingStrings:
            for t in secondMatchingString:
                matchingStrings.add(s + t)
        return matchingStrings

file = open("day-19-input", "r")
data = file.read().splitlines()

endOfRules = 0

for i in range(0, len(data)): 
    if data[i] == "":
        endOfRules = i
        break

ruleMap = {}
        
for ruleLine in data[0:endOfRules]:
    colonIndex = ruleLine.index(":")
    ruleNumber = int(ruleLine[0:colonIndex])
    ruleTokens = ruleLine[colonIndex + 1:].split()
    ruleMap[ruleNumber] = ruleTokens

processedRuleNodes = {}

ruleZero = RuleNode(0, processedRuleNodes, ruleMap)

stringsFollowingRuleZero = ruleZero.createMatchingString()

count = 0

for s in data[endOfRules + 1:]:
    if s in stringsFollowRuleZero:
        count += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-73ab70a98ce7> in <module>
#      80 ruleZero = RuleNode(0, processedRuleNodes, ruleMap)
#      81
# ---> 82 stringsFollowingRuleZero = ruleZero.createMatchingString()
#      83
#      84 count = 0
#
# <ipython-input-12-73ab70a98ce7> in createMatchingString(self)
#      46             matchingStrings = firstChoice.union(secondChoice)
#      47         else:
# ---> 48             firstMatchingStrings = self.rule[0].createMatchingString()
#      49             secondMatchingStrings = self.rule[1].createMatchingString()
#      50             matchingStrings = self.combineMatchingStrings(firstMatchingStrings, secondMatchingStrings)
#
# <ipython-input-12-73ab70a98ce7> in createMatchingString(self)
#      46             matchingStrings = firstChoice.union(secondChoice)
#      47         else:
# ...
